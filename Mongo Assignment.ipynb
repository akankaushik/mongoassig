# %% [markdown]
# # Collection
# ![Collection.png](attachment:Collection.png)

# %% [markdown]
# #Write a MongoDB query to display the fields restaurant_id, name, and zip code but exclude the field _id for all the documents in the collection restaurant.
# ![Q1.png](attachment:Q1.png)

# %% [markdown]
# Q2 Write a MongoDB query to arrange the name of the restaurants in ascending order along with all the columns.
# ![Q2.png](attachment:Q2.png)

# %% [markdown]
# Q3 Write a MongoDB query to display the first 5 restaurant in ascending order of name field.
# ![Q3.png](attachment:Q3.png)

# %% [markdown]
# Q4 Write a MongoDB query to display the next 5 restaurants after skipping first 5.
# ![Q4.png](attachment:Q4.png)

# %% [markdown]
# Q5 Write a MongoDB query to find the restaurants who achieved a score more than 90.
# ![Q5.png](attachment:Q5.png)

# %% [markdown]
# Q6 Write a MongoDB query to find the restaurants that achieved a score, more than 80 but less than 100.![Q6.png](attachment:Q6.png)

# %% [markdown]
# Q7 Write a MongoDB query to find the restaurant name, longitude and latitude and cuisine for those restaurants which contain 'Caf' as first three letters of its name.
# ![Q7.png](attachment:Q7.png)

# %% [markdown]
# Q8  Write a MongoDb query to update grade B to A in all documents.
# ![Q8.png](attachment:Q8.png)
